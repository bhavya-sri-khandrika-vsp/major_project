# %%
import pywt
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
overlapping = 0.550
columns = ["PCG"]
df = pd.read_csv('E:\Bhavya\KITSW\SEM 7\Major Project Phase 1\PCG_samples_1.csv', usecols=columns)
# n_times = 100
signal = df['PCG'][10:1000].values
# plt.figure(figsize=(30, 20))
# plt.plot(signal, alpha = overlapping)
# plt.show()



def madev(d, axis=None):
    """ Mean absolute deviation of a signal """
    return np.mean(np.absolute(d - np.mean(d, axis)), axis)

def wavelet_denoising(x, wavelet='db39', level=1):
    coeff = pywt.wavedec(x, wavelet, mode="per")
    sigma = (1/0.6745) * madev(coeff[-level])
    uthresh = sigma * np.sqrt(2 * np.log(len(x)))
    coeff[1:] = (pywt.threshold(i, value=uthresh, mode='hard') for i in coeff[1:])
    return pywt.waverec(coeff, wavelet, mode='per')

for wav in pywt.wavelist():
    try:
        filtered = wavelet_denoising(signal, wavelet=wav, level=1)
#         plt.plot(filtered,label='Filtered', color='orange', linewidth = 2)
    except:
        pass
filtered = wavelet_denoising(signal, wavelet=wav, level=1)  
signal = df['PCG'][10:1000].values
plt.figure(figsize=(30, 20))
plt.scatter(signal,filtered, label='Raw', alpha = overlapping)
plt.scatter(filtered,signal, label='Filtered', color='orange', linewidth = 2 , alpha = overlapping)
plt.legend()
plt.title(f"DWT Denoising with {wav} Wavelet", size=15)
plt.show()

# %%
import pywt
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
overlapping = 0.550
columns = ["PCG"]
df = pd.read_csv('E:\Bhavya\KITSW\SEM 7\Major Project Phase 1\PCG_samples_1.csv', usecols=columns)
# n_times = 100
signal = df['PCG'][10:1000].values
plt.figure(figsize=(30, 20))
plt.plot(signal)
plt.show()



def madev(d, axis=None):
    """ Mean absolute deviation of a signal """
    return np.mean(np.absolute(d - np.mean(d, axis)), axis)

def wavelet_denoising(x, wavelet='db38', level=2):
    coeff = pywt.wavedec(x, wavelet, mode="per")
    sigma = (1/0.6745) * madev(coeff[-level])
    uthresh = sigma * np.sqrt(2 * np.log(len(x)))
    coeff[1:] = (pywt.threshold(i, value=uthresh, mode='hard') for i in coeff[1:])
    return pywt.waverec(coeff, wavelet, mode='per')

for wav in pywt.wavelist():
    try:
        filtered = wavelet_denoising(signal, wavelet=wav, level=1)
#         plt.plot(filtered,label='Filtered', color='orange', linewidth = 2)
    except:
        pass
filtered = wavelet_denoising(signal, wavelet=wav, level=1)  
signal = df['PCG'][10:1000].values
plt.figure(figsize=(30, 20))
# plt.plot(signal,label='Raw',color='blue',linewidth = 2, alpha = overlapping)
plt.plot(filtered, label='Filtered', color='orange', linewidth = 2 , alpha = overlapping)
plt.legend()
plt.title(f"DWT Denoising with {wav} Wavelet", size=15)
plt.show()

# %%
import pywt
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
overlapping = 0.550
columns = ["PCG"]
df = pd.read_csv('E:\Bhavya\KITSW\SEM 7\Major Project Phase 1\PCG_samples_1.csv', usecols=columns)
# n_times = 100
signal = df['PCG'][10:3000].values
plt.figure(figsize=(30, 20))
plt.plot(signal)
plt.show()



def madev(d, axis=None):
    """ Mean absolute deviation of a signal """
    return np.mean(np.absolute(d - np.mean(d, axis)), axis)

def wavelet_denoising(x, wavelet='coif2', level=1):
    coeff = pywt.wavedec(x, wavelet, mode="per")
    sigma = (1/0.6745) * madev(coeff[-level])
    uthresh = sigma * np.sqrt(2 * np.log(len(x)))
    coeff[1:] = (pywt.threshold(i, value=uthresh, mode='hard') for i in coeff[1:])
    return pywt.waverec(coeff, wavelet, mode='per')

for wav in pywt.wavelist():
    try:
        filtered = wavelet_denoising(signal, wavelet=wav, level=1)
#         plt.plot(filtered,label='Filtered', color='orange', linewidth = 2)
    except:
        pass
filtered = wavelet_denoising(signal, wavelet=wav, level=1)  
signal = df['PCG'][10:3000].values
plt.figure(figsize=(30, 20))
# plt.plot(signal,label='Raw',color='blue',linewidth = 2, alpha = overlapping)
plt.plot(filtered, label='Filtered', color='orange', linewidth = 2 , alpha = overlapping)
plt.legend()
plt.title(f"DWT Denoising with {wav} Wavelet", size=15)
plt.show()

# %%
import pywt
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
overlapping = 0.550
columns = ["PCG"]
df = pd.read_csv('E:\Bhavya\KITSW\SEM 7\Major Project Phase 1\PCG_samples_1.csv', usecols=columns)
# n_times = 100
signal = df['PCG'][3:3000].values
plt.figure(figsize=(30, 20))
plt.plot(signal)
plt.show()



def madev(d, axis=None):
    """ Mean absolute deviation of a signal """
    return np.mean(np.absolute(d - np.mean(d, axis)), axis)

def wavelet_denoising(x, wavelet='db4',mode = 'smooth', level=1):
    coeff = pywt.wavedec(x, wavelet, mode="per")
    sigma = (1/0.6745) * madev(coeff[-level])
    uthresh = sigma * np.sqrt(2 * np.log(len(x)))
    coeff[1:] = (pywt.threshold(i, value=uthresh, mode='hard') for i in coeff[1:])
    return pywt.waverec(coeff, wavelet, mode='per')

for wav in pywt.wavelist():
    try:
        filtered = wavelet_denoising(signal, wavelet=wav, level=1)
#         plt.plot(filtered,label='Filtered', color='orange', linewidth = 2)
    except:
        pass
filtered = wavelet_denoising(signal, wavelet=wav, level=1)
signal = df['PCG'][3:3000].values
plt.figure(figsize=(30, 20))
# plt.plot(signal,label='Raw',color='blue',linewidth = 2, alpha = overlapping)
plt.plot(filtered, label='Filtered', color='orange', linewidth = 2)
plt.legend()
plt.title(f"DWT Denoising with {wav} Wavelet", size=15)
plt.show()

# %%
import pywt
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
overlapping = 0.550
columns = ["PCG"]
df = pd.read_csv('E:\Bhavya\KITSW\SEM 7\Major Project Phase 1\DataSet\PCG_P01_GW_36.csv', usecols=columns)
# n_times = 100
signal = df['PCG'][10:3000].values
plt.figure(figsize=(30, 20))
plt.plot(signal)
plt.show()



def madev(d, axis=None):
    """ Mean absolute deviation of a signal """
    return np.mean(np.absolute(d - np.mean(d, axis)), axis)

def wavelet_denoising(x, wavelet='coif2', level=1):
    coeff = pywt.wavedec(x, wavelet, mode="per")
    sigma = (1/0.6745) * madev(coeff[-level])
    uthresh = sigma * np.sqrt(2 * np.log(len(x)))
    coeff[1:] = (pywt.threshold(i, value=uthresh, mode='hard') for i in coeff[1:])
    return pywt.waverec(coeff, wavelet, mode='per')

for wav in pywt.wavelist():
    try:
        filtered = wavelet_denoising(signal, wavelet=wav, level=1)
#         plt.plot(filtered,label='Filtered', color='orange', linewidth = 2)
    except:
        pass
filtered = wavelet_denoising(signal, wavelet=wav, level=1)  
signal = df['PCG'][10:3000].values
plt.figure(figsize=(30, 20))
# plt.plot(signal,label='Raw',color='blue',linewidth = 2, alpha = overlapping)
plt.plot(filtered, label='Filtered', color='orange', linewidth = 2 , alpha = overlapping)
plt.legend()
plt.title(f"DWT Denoising with {wav} Wavelet", size=15)
plt.show()
